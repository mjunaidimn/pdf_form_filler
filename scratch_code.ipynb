# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/samples/sample_employer_info.csv')

# %%
df.head()
# Out:
#                       Name Of Employer As Registered Employer's TIN  \
# 0  Malaysia Offshore Mobile Production Dua (Labua...   E 9134959201
# 1                        AET Shuttle Tankers Sdn Bhd   E 9116321301
# 2                               MISC TANKERS SDN BHD    E 294468702
#
#        Category Of Employer Employer Status Tax Identification No (TIN)  \
# 0  PRIVATE SECTOR - COMPANY    IN OPERATION               C 23515364080
# 1  PRIVATE SECTOR - COMPANY    IN OPERATION               C 22370201030
# 2  PRIVATE SECTOR - COMPANY    IN OPERATION                C 2888552100
#
#   Registration no. with Companies\nCommission of Malaysia (CCM) or\nothers  \
# 0                                            LL09423
# 1                                       201001037622
# 2                                       198301001723
#
#                               Correspondence address  Telephone no.  \
# 0  UNIT LEVEL 13(A), MAIN OFFICE TOWER, FINANCIAL...     6087442816
# 1  LEVEL 23, MENARA DAYABUMI JALAN SULTAN HISHAMU...    60322674800
# 2  LEVEL 30, MENARA DAYABUMI JALAN SULTAN HISHAMU...    60322753076
#
#                         e-Mail           Furnish of C.P.8D  \
# 0  priscilla.sendi@miscbhd.com  VIA e-DATA Praisi / e-CP8D
# 1         grouptax@miscbhd.com  VIA e-DATA Praisi / e-CP8D
# 2         norzitas@miscbhd.com  VIA e-DATA Praisi / e-CP8D
#
#    Number of employees as at 31/12/2025  \
# 0                                   2.0
# 1                                   NaN
# 2                                   2.0
#
#    Number of employees subjected to Monthly Tax Deduction (MTD)  \
# 0                                                0.0
# 1                                                NaN
# 2                                                0.0
#
#    Number of new employees  Number of employees who ceased employed / died  \
# 0                      0.0                                             0.0
# 1                      NaN                                             NaN
# 2                      1.0                                             1.0
#
#    Number of employees who ceased employment and left Malaysia  \
# 0                                                0.0
# 1                                                NaN
# 2                                                0.0
#
#    Reported to LHDNM (If No. 5 is applicable)
# 0                                         0.0
# 1                                         NaN
# 2                                         0.0

# %%
def split_string(text, seperator=' ', max_len=50) -> list[str]:
        words = text.split(seperator)
        parts = []
        current = ""

        for word in words:
            # If adding this word exceeds limit, push current and start new chunk
            if len(current) + len(word) + (1 if current else 0) > max_len:
                parts.append(current)
                current = word
            else:
                current = word if not current else current + " " + word

        # Append last part if non-empty
        if current:
            parts.append(current)

        return parts

# %%
# Convert first column to uppercase
df.loc[:, 'employer_name_split'] = df.loc[:, 'Name Of Employer As Registered'].str.upper().apply(lambda x: split_string(x, max_len=50))

# %%
# Split employer name if exceeds 50 characters
df.loc[:, 'Name Of Employer As Registered 1'] = df['employer_name_split'].apply(lambda x: x[0])
df.loc[:, 'Name Of Employer As Registered 2'] = df['employer_name_split'].apply(lambda x: x[1] if len(x) > 1 else '')
df.loc[:, 'Name Of Employer As Registered 3'] = df['employer_name_split'].apply(lambda x: x[2] if len(x) > 2 else '')

# %%
split_string('Malaysia Offshore Mobile Production Dua (Labuan) Ltd (FKA GK O&M (L) Ltd)', seperator=' ', max_len=50)
# Out:
# ['Malaysia Offshore Mobile Production Dua (Labuan)',
#  'Ltd (FKA GK O&M (L) Ltd)']

# %%
split_string('UNIT LEVEL 13(A), MAIN OFFICE TOWER, FINANCIAL PARK LABUAN,JALAN MERDEKA', seperator=',', max_len=62)
# Out:
# ['UNIT LEVEL 13(A)  MAIN OFFICE TOWER  FINANCIAL PARK LABUAN', 'JALAN MERDEKA']
